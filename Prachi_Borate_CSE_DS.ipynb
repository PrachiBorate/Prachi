# %% [markdown]
# <a href="https://colab.research.google.com/github/PrachiBorate/Prachi/blob/main/Prachi_Borate_CSE_DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Pandas : It used for data manipulation and analysis.
#
# NumPy : It is a powerful Python library for numerical computing.
#
# Seaborn : It provides a high-level interface for creating attractive and informative statistical graphics.
#
# Matplotlib.pyplot : It provides a MATLAB-like interface for creating basic plots and visualizations

# %%
df=pd.read_csv("Cars_info.csv")
# df.read_csv - is used to read the data from the csv files.

# %%
df
# df is the variable in which the data is getting stored from the csv files
# Out:
#    manufacture    model    sales  resale   price  engine_s  wheelbas  width  \
# 0        Acura  Integra   16.919  16.360  21.500       1.8     101.2   67.3
# 1        Acura       TL   39.384  19.875  28.400       3.2     108.1   70.3
# 2        Acura       RL    8.588  29.725  42.000       3.5     114.6   71.4
# 3         Audi       A4   20.397  22.255  23.990       1.8     102.6   68.2
# 4         Audi       A6   18.780  23.555  33.950       2.8     108.7   76.1
# ..         ...      ...      ...     ...     ...       ...       ...    ...
# 64      Toyota  Corolla  142.535  10.025  13.108       1.8      97.0   66.7
# 65      Toyota    Camry  247.994  13.245  17.518       2.2     105.2   70.1
# 66      Toyota   Avalon   63.849  18.140  25.545       3.0     107.1   71.7
# 67  Volkswagen     Golf    9.761  11.425  14.900       2.0      98.9   68.3
# 68  Volkswagen    Jetta   83.721  13.240  16.700       2.0      98.9   68.3
#
#     length  fuel_cap
# 0    172.4      13.2
# 1    192.9      17.2
# 2    196.6      18.0
# 3    178.0      16.4
# 4    192.0      18.5
# ..     ...       ...
# 64   174.0      13.2
# 65   188.5      18.5
# 66   191.9      18.5
# 67   163.3      14.5
# 68   172.3      14.5
#
# [69 rows x 10 columns]

# %%
df.head()
# head() function is used to read the starting 5 lines from the dataset
# Out:
#   manufacture    model   sales  resale  price  engine_s  wheelbas  width  \
# 0       Acura  Integra  16.919  16.360  21.50       1.8     101.2   67.3
# 1       Acura       TL  39.384  19.875  28.40       3.2     108.1   70.3
# 2       Acura       RL   8.588  29.725  42.00       3.5     114.6   71.4
# 3        Audi       A4  20.397  22.255  23.99       1.8     102.6   68.2
# 4        Audi       A6  18.780  23.555  33.95       2.8     108.7   76.1
#
#    length  fuel_cap
# 0   172.4      13.2
# 1   192.9      17.2
# 2   196.6      18.0
# 3   178.0      16.4
# 4   192.0      18.5

# %%
df.tail()
# tail() function is used to read the last 5 lines from the dataset
# Out:
#    manufacture    model    sales  resale   price  engine_s  wheelbas  width  \
# 64      Toyota  Corolla  142.535  10.025  13.108       1.8      97.0   66.7
# 65      Toyota    Camry  247.994  13.245  17.518       2.2     105.2   70.1
# 66      Toyota   Avalon   63.849  18.140  25.545       3.0     107.1   71.7
# 67  Volkswagen     Golf    9.761  11.425  14.900       2.0      98.9   68.3
# 68  Volkswagen    Jetta   83.721  13.240  16.700       2.0      98.9   68.3
#
#     length  fuel_cap
# 64   174.0      13.2
# 65   188.5      18.5
# 66   191.9      18.5
# 67   163.3      14.5
# 68   172.3      14.5

# %%
df.sample(9)
# sample(10) - function is used to get the sample of 8 rows from the given dataset
# Out:
#       manufacture    model    sales  resale   price  engine_s  wheelbas  \
# 68     Volkswagen    Jetta   83.721  13.240  16.700       2.0      98.9
# 64         Toyota  Corolla  142.535  10.025  13.108       1.8      97.0
# 4            Audi       A6   18.780  23.555  33.950       2.8     108.7
# 32          Lexus    LS400    6.375  40.375  54.005       4.0     112.2
# 35     Mitsubishi   Mirage   26.232   8.325  13.987       1.8      98.4
# 5            Audi       A8    1.380  39.000  62.000       4.2     113.0
# 39     Mitsubishi   3000GT    0.110  20.940  25.450       3.0      97.2
# 44  Mercedes-Benz  C-Class   18.392  26.050  31.750       2.3     105.9
# 45  Mercedes-Benz  E-Class   27.602  41.450  49.900       3.2     111.5
#
#     width  length  fuel_cap
# 68   68.3   172.3      14.5
# 64   66.7   174.0      13.2
# 4    76.1   192.0      18.5
# 32   72.0   196.7      22.5
# 35   66.5   173.6      13.2
# 5    74.0   198.2      23.7
# 39   72.4   180.3      19.8
# 44   67.7   177.4      16.4
# 45   70.8   189.4      21.1

# %%
df.info()
# info() It is used to get the Information of about each and every columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   manufacture  69 non-null     object
#  1   model        69 non-null     object
#  2   sales        69 non-null     float64
#  3   resale       69 non-null     float64
#  4   price        69 non-null     float64
#  5   engine_s     69 non-null     float64
#  6   wheelbas     69 non-null     float64
#  7   width        69 non-null     float64
#  8   length       69 non-null     float64
#  9   fuel_cap     69 non-null     float64
# dtypes: float64(8), object(2)
# memory usage: 5.5+ KB

# %%
df.dtypes
# dtypes - It is used to get the datatype of the specified columns from the given datasets.
# Out:
# manufacture     object
# model           object
# sales          float64
# resale         float64
# price          float64
# engine_s       float64
# wheelbas       float64
# width          float64
# length         float64
# fuel_cap       float64
# dtype: object

# %%
df.count()
# count() method counts the number of not empty values for each row, or column
# Out:
# manufacture    69
# model          69
# sales          69
# resale         69
# price          69
# engine_s       69
# wheelbas       69
# width          69
# length         69
# fuel_cap       69
# dtype: int64

# %%
df.shape
'''  It is used to determine the dimensions or the size of an array or DataFrame.
69 --> Rows
10--> Columns'''
# Out:
# (69, 10)

# %%
df.columns
# columns - It will display the column names
# Out:
# Index(['manufacture', 'model', 'sales', 'resale', 'price', 'engine_s',
#        'wheelbas', 'width', 'length', 'fuel_cap'],
#       dtype='object')

# %%
df['price'].mean()
# mean() It is used to find the mean of the required column data
# Out:
# 26.186362318840583

# %%
df['price'].median()
# median() It is used to find the mean of the required column data
# Out:
# 21.665

# %%
df['price'].std()
#std() It is used to find the Standard Deviation of the required column data
# Out:
# 13.703984561144567

# %%
df['price'].mode()
# mode() -  It is used to find the mode of the required column data
# Out:
# 0      9.235
# 1      9.699
# 2     10.685
# 3     11.799
# 4     12.070
#        ...
# 64    49.900
# 65    54.005
# 66    62.000
# 67    71.020
# 68    74.970
# Name: price, Length: 69, dtype: float64

# %%
df.describe()
# describe() - It is used to describe the dataset into the count,mean,std,min,25%,50%(median),75%,max
# Out:
#             sales     resale      price   engine_s    wheelbas      width  \
# count   69.000000  69.000000  69.000000  69.000000   69.000000  69.000000
# mean    46.429971  18.526377  26.186362   2.857971  105.746377  70.553623
# std     47.587680  11.756949  13.703985   0.873197    6.807858   3.103204
# min      0.110000   5.160000   9.235000   1.000000   92.600000  62.600000
# 25%     13.462000  11.030000  16.540000   2.000000  101.300000  68.400000
# 50%     26.529000  14.010000  21.665000   2.800000  106.400000  70.300000
# 75%     70.227000  20.940000  31.750000   3.500000  109.000000  72.700000
# max    247.994000  67.550000  74.970000   4.600000  131.000000  78.200000
#
#            length   fuel_cap
# count   69.000000  69.000000
# mean   185.310145  17.071014
# std     12.997071   2.930022
# min    149.400000  10.300000
# 25%    176.000000  15.200000
# 50%    186.000000  17.000000
# 75%    193.400000  19.000000
# max    215.300000  24.300000

# %%
df['manufacture'].value_counts()
# value_counts() --> It will count the no. of times the specfic column name present in the dataset
# Out:
# Mitsubishi       6
# Pontiac          4
# Acura            3
# Jeep             3
# Toyota           3
# Saturn           3
# Porsche          3
# Plymouth         3
# Oldsmobile       3
# Mercury          3
# Audi             3
# Lexus            3
# Hyundai          3
# Honda            3
# Lincoln          2
# Ford             2
# Mercedes-Benz    2
# Nissan           2
# Dodge            2
# Chrysler         2
# Cadillac         2
# Chevrolet        2
# Buick            2
# BMW              2
# Volkswagen       2
# Infiniti         1
# Name: manufacture, dtype: int64

# %%
df["price"].unique()
 #list of unique entries
# Out:
# array([21.5  , 28.4  , 42.   , 23.99 , 33.95 , 62.   , 33.4  , 38.9  ,
#        21.975, 13.96 ,  9.235, 27.885, 39.895, 39.665, 16.48 , 28.34 ,
#        16.98 , 19.565, 12.07 , 21.56 , 20.55 , 26.6  , 26.   ,  9.699,
#        11.799, 14.999, 29.465, 14.46 , 21.62 , 26.895, 31.505, 37.805,
#        54.005, 39.08 , 43.33 , 13.987, 19.047, 17.357, 24.997, 25.45 ,
#        31.807, 16.24 , 16.54 , 19.035, 31.75 , 49.9  , 20.39 , 26.249,
#        18.145, 36.229, 31.598, 12.64 , 16.08 , 18.85 , 21.61 , 19.72 ,
#        25.31 , 21.665, 41.43 , 71.02 , 74.97 , 10.685, 12.535, 14.29 ,
#        13.108, 17.518, 25.545, 14.9  , 16.7  ])

# %%
df.sort_values(["engine_s"])
# .sort_values() - It will sort the values and provides you the data in the sorting manne
# Out:
#    manufacture        model    sales  resale   price  engine_s  wheelbas  \
# 10   Chevrolet        Metro   21.855   5.160   9.235       1.0      93.1
# 23     Hyundai       Accent   41.184   5.860   9.699       1.5      96.1
# 0        Acura      Integra   16.919  16.360  21.500       1.8     101.2
# 64      Toyota      Corolla  142.535  10.025  13.108       1.8      97.0
# 3         Audi           A4   20.397  22.255  23.990       1.8     102.6
# ..         ...          ...      ...     ...     ...       ...       ...
# 50  Oldsmobile      Bravada   20.017  19.925  31.598       4.3     107.0
# 12    Cadillac      DeVille   63.729  22.525  39.895       4.6     115.3
# 13    Cadillac     Eldorado    6.536  25.725  39.665       4.6     108.0
# 33     Lincoln  Continental   13.798  20.525  39.080       4.6     109.0
# 34     Lincoln     Town car   48.911  21.725  43.330       4.6     117.7
#
#     width  length  fuel_cap
# 10   62.6   149.4      10.3
# 23   65.7   166.7      11.9
# 0    67.3   172.4      13.2
# 64   66.7   174.0      13.2
# 3    68.2   178.0      16.4
# ..    ...     ...       ...
# 50   67.8   181.2      17.5
# 12   74.5   207.2      18.5
# 13   75.5   200.6      19.0
# 33   73.6   208.5      20.0
# 34   78.2   215.3      19.0
#
# [69 rows x 10 columns]

# %%
df.isnull().sum()
# isnull() - It will Return u the no. of the empty cells in the row
# Out:
# manufacture    0
# model          0
# sales          0
# resale         0
# price          0
# engine_s       0
# wheelbas       0
# width          0
# length         0
# fuel_cap       0
# dtype: int64

# %%
df.drop(["engine_s","wheelbas"],axis=1,inplace=True)
# .drop() -  It is used to delete the specified columns

# %%
df.head()
# Checking for the deleted columns
# Out:
#   manufacture    model   sales  resale  price  width  length  fuel_cap
# 0       Acura  Integra  16.919  16.360  21.50   67.3   172.4      13.2
# 1       Acura       TL  39.384  19.875  28.40   70.3   192.9      17.2
# 2       Acura       RL   8.588  29.725  42.00   71.4   196.6      18.0
# 3        Audi       A4  20.397  22.255  23.99   68.2   178.0      16.4
# 4        Audi       A6  18.780  23.555  33.95   76.1   192.0      18.5

# %%
df.dropna(inplace=True)
# dropna() --> It is used to delete the rows which have very less null values and then bring the data in the equal manner.

# %%
df.isnull().sum()
# There is no null cell in the rows
# Out:
# manufacture    0
# model          0
# sales          0
# resale         0
# price          0
# width          0
# length         0
# fuel_cap       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   manufacture  69 non-null     object
#  1   model        69 non-null     object
#  2   sales        69 non-null     float64
#  3   resale       69 non-null     float64
#  4   price        69 non-null     float64
#  5   width        69 non-null     float64
#  6   length       69 non-null     float64
#  7   fuel_cap     69 non-null     float64
# dtypes: float64(6), object(2)
# memory usage: 4.4+ KB

# %% [markdown]
# DETECTING OUTLIER
#
# Outlier --> It is an extreme value that falls far outside the typical range of values in a dataset.
#
# It is a Univarient Analysis
#
# Because we are analyzing using the single variable

# %%
sns.boxplot(x=df["width"])
# There is no outlier in the width column
# Out:
# <Axes: xlabel='width'>

# %%
sns.boxplot(x=df['price'])
# There are outlier in the price  column
# Out:
# <Axes: xlabel='price'>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# This Calculates Interquartile Range (IQR) for each column in 25 % and 75 % and then it will substract to get the 50% of Interquartile Range (IQR)
# Out:
# sales       56.765
# resale       9.910
# price       15.210
# width        4.300
# length      17.400
# fuel_cap     3.800
# dtype: float64
# <ipython-input-125-71817ab3c8cf>:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1 = df.quantile(0.25)
# <ipython-input-125-71817ab3c8cf>:2: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q3 = df.quantile(0.75)

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# <ipython-input-126-f4e1682787c4>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
# (58, 8)

# %%
sns.boxplot(x=df['price'])
# Outliers are removed sucessfully
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# EDA (Exploratory Data Analysis)
#
# It is used to understand the main characteristics, patterns, and insights hidden in the data.

# %%
plt.scatter(df['manufacture'],df['price'])

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [manufacture, model, sales, resale, price, width, length, fuel_cap]
# Index: []

# %%
duplicate_rows_df=df[df.duplicated()]
print("Number of duplicate rows: ",duplicate_rows_df.shape)
# Out:
# Number of duplicate rows:  (0, 8)

# %%
df.count()
# Out:
# manufacture    58
# model          58
# sales          58
# resale         58
# price          58
# width          58
# length         58
# fuel_cap       58
# dtype: int64

# %% [markdown]
# Scatter Plot :-
#
# It is Bivarent analysis because the 2 variables that is x and y are used.
# It represents data points as individual dots on a two-dimensional plane, with one variable on the x-axis and the other variable on the y-axis. Each
# dot represents an observation or data point.
#
# In this also manufacture is the x axis whereas the price  is the y axis

# %%
df=df.drop_duplicates()
df.head(5)
# Out:
#   manufacture    model   sales  resale  price  width  length  fuel_cap
# 0       Acura  Integra  16.919  16.360  21.50   67.3   172.4      13.2
# 1       Acura       TL  39.384  19.875  28.40   70.3   192.9      17.2
# 2       Acura       RL   8.588  29.725  42.00   71.4   196.6      18.0
# 3        Audi       A4  20.397  22.255  23.99   68.2   178.0      16.4
# 4        Audi       A6  18.780  23.555  33.95   76.1   192.0      18.5

# %%
print(df.isnull().sum())
# Out:
# manufacture    0
# model          0
# sales          0
# resale         0
# price          0
# width          0
# length         0
# fuel_cap       0
# dtype: int64

# %%
pie=df['manufacture'].value_counts()
pie
# Out:
# Mitsubishi       6
# Pontiac          4
# Acura            3
# Saturn           3
# Plymouth         3
# Oldsmobile       3
# Mercury          3
# Honda            3
# Hyundai          3
# Lexus            2
# Toyota           2
# Nissan           2
# Lincoln          2
# Jeep             2
# Audi             2
# Ford             2
# Chrysler         2
# Cadillac         2
# Buick            2
# Volkswagen       2
# Infiniti         1
# Mercedes-Benz    1
# Dodge            1
# Chevrolet        1
# BMW              1
# Name: manufacture, dtype: int64

# %%
pie.plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='manufacture'>

# %%
df["fuel_cap"].value_counts().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: ylabel='fuel_cap'>

# %% [markdown]
# Pie Chart:-
#
# It is univarient analysis , as single variable is used.
#
# In this manufacture and fuel_cap can show the manufacture in the pie format.
# It is called a "pie chart" because the chart resembles a pie that is divided into slices, with each slice representing a particular category or data point. The size of each slice corresponds to the proportion or percentage of the whole that each category represents.

# %%
sns.catplot(x ='model', hue ='fuel_cap',kind ='count', data = df)

# %% [markdown]
# Count Plot :-
#
# In the Countplots height of each bar represents the number of occurrences of each category in the dataset. Countplots are particularly useful
# for visualizing the frequency of different categories and identifying the most common or least common categories in the data.
# In this the number of the fuel_cap released in each model.

# %%
sns.displot(df['fuel_cap'],kde=True)

# %% [markdown]
# Displot :-
# displot is used to create a histogram to visualize the distribution of a numerical variable.
# It is used to create a KDE plot to visualize the estimated probability density function of a numerical variable. KDE plots show the smoothed
# continuous representation of the data distribution.

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="PuOr",annot=True)
c
# Out:
# <ipython-input-145-38bf0624e2ab>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#              sales    resale     price     width    length  fuel_cap
# sales     1.000000 -0.378367 -0.294835 -0.040256  0.011687 -0.110997
# resale   -0.378367  1.000000  0.887683  0.355059  0.361601  0.553830
# price    -0.294835  0.887683  1.000000  0.568744  0.607940  0.640110
# width    -0.040256  0.355059  0.568744  1.000000  0.737688  0.556030
# length    0.011687  0.361601  0.607940  0.737688  1.000000  0.503371
# fuel_cap -0.110997  0.553830  0.640110  0.556030  0.503371  1.000000

# %% [markdown]
# Heatmaps :-
#
# The colors on a heatmap are used to represent the magnitude or density of the data points at different locations, with warmer colors typically indicating higher values, and cooler colors indicating lower values.

# %% [markdown]
# DATA PREPROCESSING

# %%
x=df.iloc[:,0:5]
x
# Out:
#       manufacture        model    sales  resale   price
# 0           Acura      Integra   16.919  16.360  21.500
# 1           Acura           TL   39.384  19.875  28.400
# 2           Acura           RL    8.588  29.725  42.000
# 3            Audi           A4   20.397  22.255  23.990
# 4            Audi           A6   18.780  23.555  33.950
# 6             BMW         328i    9.231  28.675  33.400
# 8           Buick      Century   91.561  12.475  21.975
# 9       Chevrolet        Prizm   32.299   9.125  13.960
# 11          Buick      LeSabre   83.257  13.360  27.885
# 12       Cadillac      DeVille   63.729  22.525  39.895
# 13       Cadillac     Eldorado    6.536  25.725  39.665
# 14       Chrysler       Cirrus   32.306  12.640  16.480
# 15       Chrysler          LHS   13.462  17.325  28.340
# 16          Dodge       Dakota  111.313  11.260  16.980
# 18           Ford       Escort   70.227   7.425  12.070
# 19           Ford      Mustang  113.369  12.760  21.560
# 20          Honda         CR-V   73.203  17.710  20.550
# 21          Honda     Passport   12.855  17.525  26.600
# 22          Honda      Odyssey   76.029  19.490  26.000
# 23        Hyundai       Accent   41.184   5.860   9.699
# 24        Hyundai      Elantra   66.692   7.825  11.799
# 25        Hyundai       Sonata   29.450   8.910  14.999
# 26       Infiniti          I30   23.713  19.690  29.465
# 27           Jeep     Wrangler   55.557  13.475  14.460
# 28           Jeep     Cherokee   80.556  13.775  21.620
# 30          Lexus        ES300   24.072  26.975  31.505
# 31          Lexus        GS300   12.698  32.075  37.805
# 33        Lincoln  Continental   13.798  20.525  39.080
# 34        Lincoln     Town car   48.911  21.725  43.330
# 35     Mitsubishi       Mirage   26.232   8.325  13.987
# 36     Mitsubishi      Eclipse   42.541  10.395  19.047
# 37     Mitsubishi       Galant   55.616  10.595  17.357
# 38     Mitsubishi     Diamante    5.711  16.575  24.997
# 39     Mitsubishi       3000GT    0.110  20.940  25.450
# 40     Mitsubishi      Montero   11.337  19.125  31.807
# 41        Mercury     Mystique   14.351   8.800  16.240
# 42        Mercury       Cougar   26.529  13.890  16.540
# 43        Mercury        Sable   67.956  11.030  19.035
# 44  Mercedes-Benz      C-Class   18.392  26.050  31.750
# 46         Nissan       Altima   88.094  11.295  20.390
# 47         Nissan       Maxima   79.853  15.125  26.249
# 48     Oldsmobile      Cutlass    1.112  11.240  18.145
# 49     Oldsmobile       Aurora   14.690  19.890  36.229
# 50     Oldsmobile      Bravada   20.017  19.925  31.598
# 51       Plymouth         Neon   32.734   7.750  12.640
# 52       Plymouth       Breeze    5.240   9.800  16.080
# 53       Plymouth      Voyager   24.155  12.025  18.850
# 54        Pontiac      Sunfire   51.645  13.790  21.610
# 55        Pontiac     Grand Am  131.097  10.290  19.720
# 56        Pontiac     Firebird   19.911  17.805  25.310
# 57        Pontiac   Grand Prix   92.364  14.010  21.665
# 61         Saturn           SL   80.620   9.200  10.685
# 62         Saturn           SC   24.546  10.590  12.535
# 63         Saturn           SW    5.223  10.790  14.290
# 64         Toyota      Corolla  142.535  10.025  13.108
# 66         Toyota       Avalon   63.849  18.140  25.545
# 67     Volkswagen         Golf    9.761  11.425  14.900
# 68     Volkswagen        Jetta   83.721  13.240  16.700

# %% [markdown]
# In x axis we r including all the columns except the targeted row which will be the y axis

# %%
y=df.iloc[:,5]
y
# Out:
# 0     67.3
# 1     70.3
# 2     71.4
# 3     68.2
# 4     76.1
# 6     68.5
# 8     72.7
# 9     66.7
# 11    73.5
# 12    74.5
# 13    75.5
# 14    71.0
# 15    74.4
# 16    71.5
# 18    67.0
# 19    73.1
# 20    68.9
# 21    70.4
# 22    75.6
# 23    65.7
# 24    66.9
# 25    71.6
# 26    70.2
# 27    66.7
# 28    69.4
# 30    70.5
# 31    70.9
# 33    73.6
# 34    78.2
# 35    66.5
# 36    68.9
# 37    68.5
# 38    70.3
# 39    72.4
# 40    69.9
# 41    69.1
# 42    69.6
# 43    73.0
# 44    67.7
# 46    69.1
# 47    70.3
# 48    69.4
# 49    74.4
# 50    67.8
# 51    74.4
# 52    71.0
# 53    76.8
# 54    68.4
# 55    70.4
# 56    74.5
# 57    72.7
# 61    66.4
# 62    66.4
# 63    66.4
# 64    66.7
# 66    71.7
# 67    68.3
# 68    68.3
# Name: width, dtype: float64

# %% [markdown]
# In y axis we are  including the targeted row only.
# Which will going to calculate and give us the value of the data.

# %% [markdown]
# ENCODING :-
#
# In Encoding we will convert all the object datatype of the column to the integer for the Machine Learning Process

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# OriginalEncoder :-
#
# It is used for encoding categorical features into ordinal integers

# %%
oe=OrdinalEncoder()
x[["manufacture","model","sales"]]=oe.fit_transform(x[["manufacture","model","sales"]])
x
# Out:
#     manufacture  model  sales  resale   price
# 0           0.0   34.0   16.0  16.360  21.500
# 1           0.0   54.0   32.0  19.875  28.400
# 2           0.0   47.0    6.0  29.725  42.000
# 3           1.0    2.0   21.0  22.255  23.990
# 4           1.0    3.0   18.0  23.555  33.950
# 6           2.0    1.0    7.0  28.675  33.400
# 8           3.0   12.0   52.0  12.475  21.975
# 9           5.0   46.0   29.0   9.125  13.960
# 11          3.0   37.0   49.0  13.360  27.885
# 12          4.0   20.0   39.0  22.525  39.895
# 13          4.0   25.0    5.0  25.725  39.665
# 14          6.0   14.0   30.0  12.640  16.480
# 15          6.0   36.0   12.0  17.325  28.340
# 16          7.0   19.0   54.0  11.260  16.980
# 18          8.0   26.0   43.0   7.425  12.070
# 19          8.0   41.0   55.0  12.760  21.560
# 20          9.0   11.0   44.0  17.710  20.550
# 21          9.0   45.0   11.0  17.525  26.600
# 22          9.0   44.0   45.0  19.490  26.000
# 23         10.0    4.0   33.0   5.860   9.699
# 24         10.0   24.0   41.0   7.825  11.799
# 25         10.0   52.0   28.0   8.910  14.999
# 26         11.0   33.0   22.0  19.690  29.465
# 27         12.0   57.0   37.0  13.475  14.460
# 28         12.0   13.0   47.0  13.775  21.620
# 30         13.0   22.0   23.0  26.975  31.505
# 31         13.0   28.0   10.0  32.075  37.805
# 33         14.0   15.0   13.0  20.525  39.080
# 34         14.0   55.0   35.0  21.725  43.330
# 35         17.0   39.0   26.0   8.325  13.987
# 36         17.0   23.0   34.0  10.395  19.047
# 37         17.0   29.0   38.0  10.595  17.357
# 38         17.0   21.0    4.0  16.575  24.997
# 39         17.0    0.0    0.0  20.940  25.450
# 40         17.0   40.0    9.0  19.125  31.807
# 41         16.0   42.0   14.0   8.800  16.240
# 42         16.0   17.0   27.0  13.890  16.540
# 43         16.0   51.0   42.0  11.030  19.035
# 44         15.0   10.0   17.0  26.050  31.750
# 46         18.0    5.0   51.0  11.295  20.390
# 47         18.0   38.0   46.0  15.125  26.249
# 48         19.0   18.0    1.0  11.240  18.145
# 49         19.0    6.0   15.0  19.890  36.229
# 50         19.0    8.0   20.0  19.925  31.598
# 51         20.0   43.0   31.0   7.750  12.640
# 52         20.0    9.0    3.0   9.800  16.080
# 53         20.0   56.0   24.0  12.025  18.850
# 54         21.0   53.0   36.0  13.790  21.610
# 55         21.0   31.0   56.0  10.290  19.720
# 56         21.0   27.0   19.0  17.805  25.310
# 57         21.0   32.0   53.0  14.010  21.665
# 61         22.0   49.0   48.0   9.200  10.685
# 62         22.0   48.0   25.0  10.590  12.535
# 63         22.0   50.0    2.0  10.790  14.290
# 64         23.0   16.0   57.0  10.025  13.108
# 66         23.0    7.0   40.0  18.140  25.545
# 67         24.0   30.0    8.0  11.425  14.900
# 68         24.0   35.0   50.0  13.240  16.700

# %% [markdown]
# Fit : to perform calculations on data
#
# Transform : apply that calculation
#
# Converting the Object data type of columns to the integer using fit_transform with OriginalEncoder of X-axis

# %% [markdown]
# MODEL

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# train_test_split - It is used to split a dataset into two (or more) subsets

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# x and y axis is splitted into xtrain , xtest , ytrain ,ytest
# where xtrain and xtest will give the output model then the ytrain is provided to the model which gives the predicted value of y predy  which is further compared with the ytest to be accurate

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# LogisticRegression - It is used to perform logistic regression
#
# classification_report - It provides a comprehensive report with metrics such as precision, recall, F1-score, and support for both classes
# (positive and negative). It helps you understand the performance of the model for each class and overall accuracy.
#
# confusion_matrix - It provides a matrix that compares the predicted class labels against the actual class labels. It helps to visualize the
# number of true positives, false positives, true negatives, and false negatives, which is useful for understanding the model's performance and
# identifying potential areas for improvement.

# %%
#step1 -: import the model
from sklearn.linear_model import LinearRegression
#step2 -: initalize the model
linreg = LinearRegression()
#step3 -: train the model -> m & c
linreg.fit(xtrain, ytrain)
#step4 -: make prediction
ypred = linreg.predict(xtest)

# %% [markdown]
# step1 -: import the model
#
# step2 -: initalize the model
#
# step3 -: train the model -> m & c
#
# step4-: make prediction

# %%
from sklearn.metrics import r2_score
print(f"Accuracy : {r2_score(ytest, ypred)}")
# Out:
# Accuracy : -0.31057730007594553

# %% [markdown]
# Accuracy :-
#  It is used to see how much accurate the data it is providing by comparing the ypred and ytest

# %%
linreg.intercept_
# linreg.intercept_ :- It provides the value of the intercept
# Out:
# 64.9721618528454

# %%
linreg.coef_
# linreg.coef_ :-  It represents the coefficients associated with each input feature in the linear regression equation.
# Out:
# array([-0.01869733, -0.01089202,  0.02269267, -0.24887563,  0.40175462])

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
ypred=model.predict(x)

# %% [markdown]
# object of linear regression class
#
# training of model
#
# testing of model
#
# ypred stores the predicted value of y store hai

# %%
ypred
# Out:
# array([69.56616942, 71.78053078, 73.76162492, 68.35998326, 71.94846549,
#        69.96016142, 71.13546759, 69.09025032, 73.56379635, 75.1931423 ,
#        73.70473248, 68.57288001, 71.97445175, 69.60746502, 68.74957533,
#        71.31912218, 68.79464204, 71.31377736, 70.93346081, 67.80879335,
#        68.45147917, 69.62670139, 71.77684698, 68.19367216, 70.49737639,
#        70.20225383, 71.07395359, 74.99836472, 77.23010519, 69.1538652 ,
#        70.43987222, 69.83963604, 70.48168142, 68.9604362 , 72.786902  ,
#        69.79362801, 68.17048123, 70.75991382, 70.31996619, 70.68170145,
#        72.26881413, 69.26789478, 73.92186631, 72.14286973, 68.90352037,
#        68.77331121, 70.17887493, 70.87077065, 71.15357543, 70.51088622,
#        70.76367614, 67.98693409, 67.96461944, 68.31385562, 68.35825132,
#        70.50358097, 68.15290056, 68.98646873])

# %%
from sklearn.metrics import r2_score
r2_score(y,ypred)
# Out:
# 0.44048160517752544

# %%
model.intercept_
# Out:
# 65.21973191120848

# %%
model.coef_
# Out:
# array([-0.00421149,  0.01439386,  0.01416377, -0.3081391 ,  0.40332937])

# %%
x
# Out:
#     manufacture  model  sales  resale   price
# 0           0.0   34.0   16.0  16.360  21.500
# 1           0.0   54.0   32.0  19.875  28.400
# 2           0.0   47.0    6.0  29.725  42.000
# 3           1.0    2.0   21.0  22.255  23.990
# 4           1.0    3.0   18.0  23.555  33.950
# 6           2.0    1.0    7.0  28.675  33.400
# 8           3.0   12.0   52.0  12.475  21.975
# 9           5.0   46.0   29.0   9.125  13.960
# 11          3.0   37.0   49.0  13.360  27.885
# 12          4.0   20.0   39.0  22.525  39.895
# 13          4.0   25.0    5.0  25.725  39.665
# 14          6.0   14.0   30.0  12.640  16.480
# 15          6.0   36.0   12.0  17.325  28.340
# 16          7.0   19.0   54.0  11.260  16.980
# 18          8.0   26.0   43.0   7.425  12.070
# 19          8.0   41.0   55.0  12.760  21.560
# 20          9.0   11.0   44.0  17.710  20.550
# 21          9.0   45.0   11.0  17.525  26.600
# 22          9.0   44.0   45.0  19.490  26.000
# 23         10.0    4.0   33.0   5.860   9.699
# 24         10.0   24.0   41.0   7.825  11.799
# 25         10.0   52.0   28.0   8.910  14.999
# 26         11.0   33.0   22.0  19.690  29.465
# 27         12.0   57.0   37.0  13.475  14.460
# 28         12.0   13.0   47.0  13.775  21.620
# 30         13.0   22.0   23.0  26.975  31.505
# 31         13.0   28.0   10.0  32.075  37.805
# 33         14.0   15.0   13.0  20.525  39.080
# 34         14.0   55.0   35.0  21.725  43.330
# 35         17.0   39.0   26.0   8.325  13.987
# 36         17.0   23.0   34.0  10.395  19.047
# 37         17.0   29.0   38.0  10.595  17.357
# 38         17.0   21.0    4.0  16.575  24.997
# 39         17.0    0.0    0.0  20.940  25.450
# 40         17.0   40.0    9.0  19.125  31.807
# 41         16.0   42.0   14.0   8.800  16.240
# 42         16.0   17.0   27.0  13.890  16.540
# 43         16.0   51.0   42.0  11.030  19.035
# 44         15.0   10.0   17.0  26.050  31.750
# 46         18.0    5.0   51.0  11.295  20.390
# 47         18.0   38.0   46.0  15.125  26.249
# 48         19.0   18.0    1.0  11.240  18.145
# 49         19.0    6.0   15.0  19.890  36.229
# 50         19.0    8.0   20.0  19.925  31.598
# 51         20.0   43.0   31.0   7.750  12.640
# 52         20.0    9.0    3.0   9.800  16.080
# 53         20.0   56.0   24.0  12.025  18.850
# 54         21.0   53.0   36.0  13.790  21.610
# 55         21.0   31.0   56.0  10.290  19.720
# 56         21.0   27.0   19.0  17.805  25.310
# 57         21.0   32.0   53.0  14.010  21.665
# 61         22.0   49.0   48.0   9.200  10.685
# 62         22.0   48.0   25.0  10.590  12.535
# 63         22.0   50.0    2.0  10.790  14.290
# 64         23.0   16.0   57.0  10.025  13.108
# 66         23.0    7.0   40.0  18.140  25.545
# 67         24.0   30.0    8.0  11.425  14.900
# 68         24.0   35.0   50.0  13.240  16.700

# %%
r=int(input("\n 0.Acura \t 1.Audi \t 2.BMW\t 3.Honda \n enter the manufacture: "))
a=int(input("\n0.Integral  1.A8, 2. 328i \t 3.Passport\n enter the model: "))
g=int(input("\n 0.16.919\t 1.38 \t 9.231 \t 12.855\n enter the sales: "))
m=0.0
year=int(input("\nEnter the prices : "))
unknown_y=[[r,a,g,m,year]]
ynew=model.predict(unknown_y)
print("\n\nThe prices of car: ",ynew)
# Out:
#  0.Acura 	 1.Audi 	 2.BMW	 3.Honda
#  enter the manufacture: 3
#
# 0.Integral  1.A8, 2. 328i 	 3.Passport
#  enter the model: 2
#
#  0.16.919	 1.38 	 9.231 	 12.855
#  enter the sales: 0
#
# Enter the prices : 255432
#
#
# The prices of car:  [103088.46313709]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# In this We are taking the input from the user i.e manufacture, model,sales,price
# And after taking input we are Predicting the value of the prices of car

# %% [markdown]
# SUMMARY

# %% [markdown]
# From this Dataset of cars_info
# We have found the price of car from each manufacture
# Each and Every model releases different types of the prices
# By Providing the sales value of model by manufacture and price can be predicted.
